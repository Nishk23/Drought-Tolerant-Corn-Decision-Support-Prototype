# %% [markdown]
# # Drought-Tolerant Corn Decision Support Prototype
#
# Synthetic representative data for a 10-minute KWS Assessment Center presentation.
#
# This notebook is a thin runnable wrapper around the reusable project module. It generates the synthetic data, charts, metrics, and breeder-ready outputs end to end.
#
# Important disclaimer: synthetic representative data for project demonstration only. Not a production model and not based on real KWS proprietary data.

# %%
from pathlib import Path
import sys

project_dir = Path.cwd().resolve()
if (project_dir / 'build_prototype.py').exists():
    pass
elif (project_dir.parent / 'build_prototype.py').exists():
    project_dir = project_dir.parent
else:
    project_dir = project_dir / 'drought_corn_prototype'

sys.path.insert(0, str(project_dir))
from build_prototype import main

results = main()
# Out:
# Synthetic dataset created: 3,600 rows x 32 columns
# drought_stress_label
# Normal              110
# Moderate Stress    2835
# Severe Stress       655
# Name: count, dtype: int64
#
# Unseen year metrics:
#          split            group  n_samples       mae      rmse        r2
# 0  unseen_year          overall        720  2.610004  3.319732  0.865790
# 1  unseen_year  Moderate Stress        492  2.576927  3.273757  0.808012
# 2  unseen_year    Severe Stress        228  2.681381  3.416835  0.574985
#
# Unseen location held out:
#              split                           group  n_samples       mae  \
# 3  unseen_location                    West Field 3        240  2.564529
# 4  unseen_location  West Field 3 | Moderate Stress        178  2.601213
# 5  unseen_location    West Field 3 | Severe Stress         62  2.459208
#
#        rmse        r2
# 3  3.271198  0.901254
# 4  3.372497  0.744794
# 5  2.961178  0.824739
#
# Top breeding candidates:
# ...

# %% [markdown]
# ## Outputs
#
# After running the notebook, the presentation-ready figures are written to `outputs/figures/` and the tables are written to `outputs/tables/`.
#
# Use these assets directly in slides to show the workflow from synthetic data through model validation and breeder recommendations.
